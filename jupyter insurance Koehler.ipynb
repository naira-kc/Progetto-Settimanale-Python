# %%
# Importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare e controllo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})
print(insurance_data.head())
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare e controllo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Tasformo i dati stringhe in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes': 1, 'no': 0})

# Utilizzo il one-hot encoding per la colonna 'region'
insurance_data = pd.get_dummies(insurance_data, columns=['region'], drop_first=True)

print(insurance_data.describe())

# Visualizzo le statistiche descrittive del dataset (arrotondate)
print(insurance_data.describe().round(2))
# Out:
#            age      sex      bmi  children  smoker   charges
# count  1338.00  1338.00  1338.00   1338.00  1338.0   1338.00
# mean     39.21     0.51    30.66      1.09     0.2  13270.42
# std      14.05     0.50     6.10      1.21     0.4  12110.01
# min      18.00     0.00    15.96      0.00     0.0   1121.87
# 25%      27.00     0.00    26.30      0.00     0.0   4740.29
# 50%      39.00     1.00    30.40      1.00     0.0   9382.03
# 75%      51.00     1.00    34.69      2.00     0.0  16639.91
# max      64.00     1.00    53.13      5.00     1.0  63770.43

# %%
# Importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare e controllo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Tasformo i dati stinghe in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes': 1, 'no': 0})

# Utilizzo il one-hot encoding per la colonna 'region' senza eliminare la prima colonna
insurance_data = pd.get_dummies(insurance_data, columns=['region'], drop_first=False)

# Mappa dei codici alle regioni uniche
region_columns = [col for col in insurance_data.columns if col.startswith('region_')]
region_mapping = dict(zip(insurance_data[region_columns].columns, insurance_data[region_columns].columns))

# Stampa la mappa
print("Mappa dei codici alle regioni:")
for code, region in region_mapping.items():
    print(f"Codice {code}: {region}")
# Out:
# Mappa dei codici alle regioni:
# Codice region_northeast: region_northeast
# Codice region_northwest: region_northwest
# Codice region_southeast: region_southeast
# Codice region_southwest: region_southwest

# %%
# Importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare e controllo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})
# Visualizza le regioni uniche nel dataset
unique_regions = insurance_data['region'].unique()

# Stampa i risultati
print("Regioni presenti nel dataset:")
print(unique_regions)
# Out:
# Regioni presenti nel dataset:
# ['southwest', 'southeast', 'northwest', 'northeast']
# Categories (4, object): ['northeast', 'northwest', 'southeast', 'southwest']

# %%
# Importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare e controllo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Tasformo i dati stinghe in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes': 1, 'no': 0})

# Utilizzo il one-hot encoding per la colonna 'region' senza eliminare la prima colonna
insurance_data = pd.get_dummies(insurance_data, columns=['region'], drop_first=False)

# Mappa dei codici alle regioni uniche
region_columns = [col for col in insurance_data.columns if col.startswith('region_')]
region_mapping = dict(zip(insurance_data[region_columns].columns, insurance_data[region_columns].columns))

#Creo una matrice di correlazione di tutti i dati
correlation_matrix = insurance_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Matrice di Correlazione")
plt.show()

# %%
# Importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare 
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Tasformo i dati stinghe in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes': 1, 'no': 0})

# Utilizzo il one-hot encoding per la colonna 'region' senza eliminare la prima colonna
insurance_data = pd.get_dummies(insurance_data, columns=['region'], drop_first=False)

# Mappa dei codici alle regioni uniche
region_columns = [col for col in insurance_data.columns if col.startswith('region_')]
region_mapping = dict(zip(insurance_data[region_columns].columns, insurance_data[region_columns].columns))

# Stampa le colonne disponibili nel DataFrame
print("Colonne disponibili nel DataFrame:", insurance_data.columns)
# Out:
# Colonne disponibili nel DataFrame: Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges',
#        'region_northeast', 'region_northwest', 'region_southeast',
#        'region_southwest'],
#       dtype='object')

# %%
# Importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare e controllo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})


# Creo una funzione per generare un boxplot
# Funzione per creare un boxplot
def boxplot_by_category(numeric_column, category_column, **kwargs):
    print(f"\nSto creando un boxplot di {numeric_column} in base a {category_column}")
    
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=category_column, y=numeric_column, data=insurance_data, palette="pastel", hue=category_column, dodge=True, legend=False)
    plt.title(f'Boxplot di {numeric_column} per {category_column}', fontsize=14)
    title = kwargs.get('title', None)
    if title:
        plt.title(title, fontsize=16)  
    plt.show()


# Esempi di utilizzo della funzione 
boxplot_by_category('charges', 'sex', title='Boxplot delle spese per sesso')
boxplot_by_category('charges', 'children', title='Boxplot delle spese per bambini')
boxplot_by_category('charges', 'smoker',title='Boxplot delle spese per fumatori')
# Out:
# Sto creando un boxplot di charges in base a sex
# Sto creando un boxplot di charges in base a children
# Sto creando un boxplot di charges in base a smoker

# %%
# Importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare e controllo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Tasformo i dati stinghe in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes': 1, 'no': 0})

# Utilizzo il one-hot encoding per la colonna 'region'
insurance_data = pd.get_dummies(insurance_data, columns=['region'], drop_first=True)

# Creo il grafico a dispersione tra spese, BMI e fumatori
plt.figure(figsize=(12, 8))
sns.scatterplot(x='bmi', y='charges', hue='smoker', data=insurance_data, palette={0: 'blue', 1: 'red'}, alpha=0.7)
plt.title('Grafico a Dispersione tra Spese, BMI e Fumatori', color='red', fontsize= 16)
plt.xlabel('BMI')
plt.ylabel('Spese Assicurative')
plt.legend(['Fumatori', 'Non Fumatori'])
plt.show()

# %%
# Importo le librerie necessarie:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carico il file CSV da analizzare e visualizzo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Trasformo i dati di stringa in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes': 1, 'no': 0})

# Utilizzo il one-hot encoding per la colonna 'region'
insurance_data = pd.get_dummies(insurance_data, columns=['region'], drop_first=True)

# Creo un grafico di dispersione per la correlazione tra 'bmi' e 'charges'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=insurance_data, x='bmi', y='charges', color='blue', alpha=0.7)
plt.title('Correlazione tra BMI e Costi')
plt.xlabel('BMI')
plt.ylabel('Costi')
plt.show()

# %%
# Importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare e controllo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Tasformo i dati stinghe in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes': 1, 'no': 0})

# Calcolo la correlazione tra BMI e costi assicurativi
correlation_bmi_charges = insurance_data['bmi'].corr(insurance_data['charges'])

# Stampo il risultato
print(f"Correlazione tra BMI e Costi Assicurativi: {correlation_bmi_charges}")

# Valuto la correlazione e stampo il risultato desiderato
if correlation_bmi_charges == 0:
    print("La correlazione è vicina a zero, indicando una scarsa relazione lineare.")
elif 0 < correlation_bmi_charges < 0.1:
    print("La correlazione è debole, indicando una relazione molto lieve.")
elif 0.1 <= correlation_bmi_charges < 0.3:
    print("La correlazione è leggera, indicando una relazione crescente moderata.")
elif correlation_bmi_charges >= 0.3:
    print("La correlazione è significativa, indicando una relazione crescente forte.")
else:
    print("La correlazione è negativa, indicando una relazione decrescente tra BMI e Costi Assicurativi.")

# Calcolo la correlazione tra Fumo e costi assicurativi
correlation_smoker_charges = insurance_data['smoker'].corr(insurance_data['charges'])

# Stampo il risultato
print(f"Correlazione tra Fumo e Costi Assicurativi: {correlation_smoker_charges}")

# Valuto la correlazione e stampo il risultato desiderato
if correlation_smoker_charges == 0:
    print("La correlazione è vicina a zero, indicando una scarsa relazione lineare.")
elif 0 < correlation_smoker_charges < 0.1:
    print("La correlazione è debole, indicando una relazione molto lieve.")
elif 0.1 <= correlation_smoker_charges < 0.3:
    print("La correlazione è leggera, indicando una relazione crescente moderata.")
elif correlation_smoker_charges >= 0.3:
    print("La correlazione è significativa, indicando una relazione crescente forte.")
else:
    print("La correlazione è negativa, indicando una relazione decrescente tra Fumo e Costi Assicurativi.")
# Out:
# Correlazione tra BMI e Costi Assicurativi: 0.1983409688336289
# La correlazione è leggera, indicando una relazione crescente moderata.
# Correlazione tra Fumo e Costi Assicurativi: 0.7872514304984778
# La correlazione è significativa, indicando una relazione crescente forte.

# %%
# Importo le librerie necessarie:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carico il file CSV da analizzare e visualizzo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Trasformo i dati di stringa in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes': 1, 'no': 0})

# Utilizzo il one-hot encoding per la colonna 'region'
insurance_data = pd.get_dummies(insurance_data, columns=['region'], drop_first=True)

# Calcolo la correlazione tra 'charges' e 'children'
correlation_charges_children = insurance_data['charges'].corr(insurance_data['children'])

# Creo un grafico di dispersione per la correlazione tra 'charges' e 'children'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=insurance_data, x='children', y='charges', color='green', alpha=0.7)
plt.title('Correlazione tra Numero di Figli e Costi')
plt.xlabel('Numero di Figli')
plt.ylabel('Costi')
plt.show()

# Visualizzo la correlazione calcolata
print(f"Correlazione tra costi e figli: {correlation_charges_children:.2f}")

# Valuto la correlazione e stampo il risultato desiderato
if correlation_charges_children == 0:
    print("La correlazione è vicina a zero, indicando una scarsa relazione lineare.")
elif 0 < correlation_charges_children < 0.1:
    print("La correlazione è debole, indicando una relazione molto lieve.")
elif 0.1 <= correlation_charges_children< 0.3:
    print("La correlazione è leggera, indicando una relazione crescente moderata.")
elif correlation_charges_children >= 0.3:
    print("La correlazione è significativa, indicando una relazione crescente forte.")
else:
    print("La correlazione è negativa, indicando una relazione decrescente tra Fumo e Costi Assicurativi.")
# Out:
# Correlazione tra costi e figli: 0.07
# La correlazione è debole, indicando una relazione molto lieve.

# %%
# Importo le librerie necessarie:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carico il file CSV da analizzare e visualizzo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Trasformo i dati di stringa in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes': 1, 'no': 0})

# Utilizzo il one-hot encoding per la colonna 'region'
insurance_data = pd.get_dummies(insurance_data, columns=['region'], drop_first=True)

# Calcolo la correlazione tra 'age' e 'charges'
correlation_age_charges = insurance_data['age'].corr(insurance_data['charges'])

# Creo un grafico di dispersione per la correlazione tra 'age' e 'charges'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=insurance_data, x='age', y='charges', color='purple', alpha=0.7)
plt.title('Correlazione tra Età e Costi')
plt.xlabel('Età')
plt.ylabel('Costi')
plt.show()

# Visualizzo la correlazione calcolata
print(f"Correlazione tra 'age' e 'charges': {correlation_age_charges:.2f}")
# Out:
# Correlazione tra 'age' e 'charges': 0.30

# %%
# Importo le librerie necessarie:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# Carico il file CSV da analizzare e visualizzo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Trasformo i dati di stringa in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes': 1, 'no': 0})

# Utilizzo il one-hot encoding per la colonna 'region'
insurance_data = pd.get_dummies(insurance_data, columns=['region'], drop_first=True)

# Creo un grafico a dispersione 3D per 'age', 'charges' e 'smoker'
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Punti per i non fumatori
non_smokers = insurance_data[insurance_data['smoker'] == 0]
ax.scatter(non_smokers['age'], non_smokers['charges'], non_smokers['smoker'], color='blue', label='Non Fumatori', alpha=0.7)

# Punti per i fumatori
smokers = insurance_data[insurance_data['smoker'] == 1]
ax.scatter(smokers['age'], smokers['charges'], smokers['smoker'], color='red', label='Fumatori', alpha=0.7)

ax.set_xlabel('Età')
ax.set_ylabel('Costi')
ax.set_zlabel('Fumatore (0 = No, 1 = Sì)')
ax.set_title('Relazione tra Età, Costi e Fumo')
ax.legend()
plt.show()

# %%
# Importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare e controllo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Tasformo i dati stinghe in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})

# Esploro la distribuzione di fumatori e non fumatori
sns.countplot(x='smoker', data=insurance_data, palette="pastel")
plt.title('Distribuzione di Fumatori e Non Fumatori')
plt.xlabel('Fumatore')
plt.ylabel('Conteggio')
plt.show()

# Calcolo la media dei costi assicurativi per fumatori e non fumatori
mean_charges_by_smoker = insurance_data.groupby('smoker')['charges'].mean()

# Stampo il risultato
print("Media dei costi assicurativi per fumatori e non fumatori:")
print(mean_charges_by_smoker)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_31936\4193333236.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='smoker', data=insurance_data, palette="pastel")
# Media dei costi assicurativi per fumatori e non fumatori:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %%
# Importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare e controllo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Tasformo i dati stinghe in valori numerici
insurance_data['sex'] = insurance_data['sex'].map({'female': 0, 'male': 1})
insurance_data['smoker'] = insurance_data['smoker'].map({'yes': 1, 'no': 0})

# Utilizzo il one-hot encoding per la colonna 'region' senza eliminare la prima colonna
insurance_data = pd.get_dummies(insurance_data, columns=['region'], drop_first=False)

# Funzione per visualizzare istogramma e statistiche di una colonna
def analyze_column(column_name):
    plt.figure(figsize=(10, 6))
    sns.histplot(insurance_data[column_name], kde=True, color="darkgreen")
    plt.title(f'Distribution for {column_name}', fontsize=14)
    plt.show()
    print(f"Statistics for {column_name}:\n{insurance_data[column_name].describe()}\n")

analyze_column('age')
analyze_column('bmi')
analyze_column('children')
analyze_column('charges')
# Out:
# Statistics for age:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64
# Statistics for bmi:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64
# Statistics for children:
# count    1338.000000
# mean        1.094918
# std         1.205493
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: children, dtype: float64
# Statistics for charges:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Creazione del boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x=insurance_data['age'], color='skyblue')

# Aggiunta di etichette e titoli
plt.title('Distribuzione dell\'età nella popolazione assicurativa')
plt.xlabel('Età')
plt.grid(True)

# Visualizzazione del grafico
plt.show()

# %%
#importo le librerie che mi servono:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggiungo il file csv da analizzare e controllo le prime righe
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})


# Creo un grafico a barre per mostrare la media dei costi per uomini e donne
plt.figure(figsize=(8, 6))
sns.barplot(x='sex', y='charges', data=insurance_data, color="skyblue", errorbar=None)
plt.title('Confronto della Media dei Costi Assicurativi tra Uomini e Donne')
plt.xlabel('Genere')
plt.ylabel('Media Costi Assicurativi')
plt.show()

# %%
import pandas as pd

# Aggiungo il file csv da analizzare
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Calcola la media dei costi per donne e uomini
mean_charges_by_gender = insurance_data.groupby('sex')['charges'].mean()

# Stampa i risultati
print(f"Media dei costi per donne: {mean_charges_by_gender.loc['female']}")
print(f"Media dei costi per uomini: {mean_charges_by_gender.loc['male']}")
# Out:
# Media dei costi per donne: 12569.578843835347
# Media dei costi per uomini: 13956.751177721893

# %%
import pandas as pd

# Aggiungo il file csv da analizzare
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Calcolo la media dei costi per fumatori e non fumatori
mean_charges_by_smoker = insurance_data.groupby('smoker')['charges'].mean()

# Stampo i risultati
print(f"Media dei costi per non fumatori: {mean_charges_by_smoker[0]}")
print(f"Media dei costi per fumatori: {mean_charges_by_smoker[1]}")
# Out:
# Media dei costi per non fumatori: 8434.268297856202
# Media dei costi per fumatori: 32050.23183153285
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_31936\903742313.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Media dei costi per non fumatori: {mean_charges_by_smoker[0]}")
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_31936\903742313.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Media dei costi per fumatori: {mean_charges_by_smoker[1]}")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carica il DataFrame
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Conta le persone in ciascuna regione
region_counts = insurance_data['region'].value_counts()

# Calcola la percentuale di persone in ciascuna regione
region_percentages = (region_counts / len(insurance_data)) * 100

# Visualizza il grafico a barre
plt.figure(figsize=(10, 6))
region_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Numero di Persone per Regione', fontsize=14)
plt.xlabel('Regione', fontsize=12)
plt.ylabel('Numero di Persone', fontsize=12)
plt.show()

# Stampa le percentuali
print("Percentuale di Persone per Regione:")
print(region_percentages)
# Out:
# Percentuale di Persone per Regione:
# region
# southeast    27.204783
# northwest    24.289985
# southwest    24.289985
# northeast    24.215247
# Name: count, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carica il DataFrame
insurance_data = pd.read_csv("./insurance.csv", dtype={'region': 'category'})

# Calcola la media dei costi assicurativi per ciascun numero di figli
mean_charges_by_children = insurance_data.groupby('children')['charges'].mean()

# Visualizza il grafico a barre
plt.figure(figsize=(10, 6))
mean_charges_by_children.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Media dei Costi Assicurativi per Numero di Figli', fontsize=14)
plt.xlabel('Numero di Figli', fontsize=12)
plt.ylabel('Media dei Costi Assicurativi', fontsize=12)
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

file_name = "insurance.csv"

try:
	insurance = pd.read_csv(file_name)
except:
	print("Errore caricamento")
	
dati = pd.DataFrame(insurance)
print(dati)

#Set dei valori di riferimento per il BMI
normal_bmi = 28


dati['Risk_bmi'] = np.where(dati['bmi'] >= 28, 0.05*dati['charges'], 0)
dati['Risk_smoker'] = np.where(dati['smoker'] == 'yes', 0.05*dati['charges'], 0)
dati['Total_risk'] = (dati['Risk_bmi']+ dati['Risk_smoker'])*dati['children']
dati['New_total'] = (dati['charges']+dati['Total_risk'])

print(dati)

tab = dati.groupby('age')[['New_total','charges']].sum()

tab.plot(kind = "bar")

plt.xlabel("Età", color = "b")
plt.ylabel("Valore", color = "b")
plt.title("Charge assicurativa prima e dopo l'aumento'", color = "b")
plt.legend(["Nuova rata", "Vecchia rata"])

plt.show()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#          Risk_bmi  Risk_smoker   Total_risk     New_total
# 0        0.000000   844.246200     0.000000  16884.924000
# 1       86.277615     0.000000    86.277615   1811.829915
# 2      222.473100     0.000000   667.419300   5116.881300
# 3        0.000000     0.000000     0.000000  21984.470610
# 4      193.342760     0.000000     0.000000   3866.855200
# ...           ...          ...          ...           ...
# 1333   530.027415     0.000000  1590.082245  12190.630545
# 1334   110.299040     0.000000     0.000000   2205.980800
# 1335    81.491675     0.000000     0.000000   1629.833500
# 1336     0.000000     0.000000     0.000000   2007.945000
# 1337  1457.068015  1457.068015     0.000000  29141.360300
#
# [1338 rows x 11 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

insurance_data = pd.read_csv ("insurance.csv")

plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
sns.histplot(insurance_data['age'], kde=True, color='skyblue')
plt.title('Distribuzione di eta')

plt.subplot(2, 2, 2)
sns.histplot(insurance_data['bmi'], kde=True, color='salmon')
plt.title('Distribuzione di BMI')

plt.subplot(2, 2, 3)
sns.countplot(x='children', data=insurance_data, palette='pastel')
plt.title('Distribuzione della quantita dei bambini')

plt.subplot(2, 2, 4)
sns.countplot(x='smoker', data=insurance_data, palette='pastel')
plt.title('Distribuzione degli fumatori')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_31936\45291712.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='children', data=insurance_data, palette='pastel')
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_31936\45291712.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='smoker', data=insurance_data, palette='pastel')
# Text(0.5, 1.0, 'Distribuzione degli fumatori')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

insurance_data = pd.read_csv ("insurance.csv")

"""Analisi della regione più costosa"""

# Boxplot dei costi per regione
plt.figure(figsize=(12, 8))
sns.boxplot(data=insurance_data, x='region', y='charges', palette='Set1')
plt.title('Boxplot dei Costi per Regione')
plt.xlabel('Regione')
plt.ylabel('Costi (Charges)')
plt.show()

# le colonne in liste

age_list = insurance_data['age'].tolist()
sex_list = insurance_data['sex'].tolist()
bmi_list = insurance_data['bmi'].tolist()
children_list = insurance_data['children'].tolist()
smoker_list = insurance_data['smoker'].tolist()
region_list = insurance_data['region'].tolist()
charges_list = insurance_data['charges'].tolist()

def filter_data(age_list, smoker_list, children_list, charges_list, bmi_list, region_list):
    # Creazione di un DataFrame dai dati delle liste
    df = pd.DataFrame({
        'age': age_list,
        'smoker': smoker_list,
        'children': children_list,
        'charges': charges_list,
        'bmi': bmi_list,
        'region': region_list,
         'sex': sex_list
    })

    # Filtraggio del DataFrame secondo i criteri: Giovani, senza figli e in salute (no fumo, no sovrapeso)
    filtered_df = df[(df['smoker'] == 'no') & (df['children'] == 0) & (df['age'] < 30) & (df['bmi'] >= 18.5) & (df['bmi'] <= 24.9) & (df['region'] != "southeast") & (df['sex'] != "male")]

    return filtered_df

# Chiamata della funzione con le liste
filtered_df = filter_data(age_list, smoker_list, children_list, charges_list, bmi_list, region_list)

# Stampa del DataFrame risultante
print(filtered_df)


print(filtered_df.describe())
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_31936\1669023933.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=insurance_data, x='region', y='charges', palette='Set1')
#       age smoker  children     charges     bmi     region     sex
# 277    22     no         0  2150.46900  24.300  southwest  female
# 311    19     no         0  1737.37600  24.700  southwest  female
# 388    26     no         0  3176.81590  22.610  northwest  female
# 579    25     no         0  3206.49135  23.465  northeast  female
# 714    24     no         0  2457.50200  22.600  southwest  female
# 792    22     no         0  2731.91220  23.180  northeast  female
# 816    24     no         0  2842.76075  24.225  northwest  female
# 848    27     no         0  2974.12600  24.100  southwest  female
# 882    21     no         0  2585.85065  22.135  northeast  female
# 899    19     no         0  2117.33885  22.515  northwest  female
# 972    22     no         0  2527.81865  20.235  northwest  female
# 1054   27     no         0  3353.47030  21.470  northwest  female
# 1129   19     no         0  1728.89700  18.600  southwest  female
# 1137   26     no         0  3176.28770  22.230  northwest  female
# 1316   19     no         0  1731.67700  20.600  southwest  female
#              age  children      charges        bmi
# count  15.000000      15.0    15.000000  15.000000
# mean   22.800000       0.0  2566.586223  22.464333
# std     3.004758       0.0   568.055039   1.695156
# min    19.000000       0.0  1728.897000  18.600000
# 25%    20.000000       0.0  2133.903925  21.802500
# 50%    22.000000       0.0  2585.850650  22.600000
# 75%    25.500000       0.0  3075.206850  23.782500
# max    27.000000       0.0  3353.470300  24.700000
